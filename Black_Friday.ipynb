# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537549  1004734  P00345842      M  51-55           1             B
# 537551  1004735  P00313442      M  46-50           3             C
# 537562  1004736  P00146742      M  18-25          20             A
# 537571  1004737  P00221442      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %% [markdown]
# ## Analysing Columns

# %%
df["User_ID"].nunique()
# Out:
# 5891

# %%
df["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df["Product_ID"].nunique()
# Out:
# 3623

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Occupation"].nunique()
# Out:
# 21

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1])

# %%
df["Product_Category_1"].nunique()
# Out:
# 18

# %%
df["Purchase"].sum()
# Out:
# np.int64(5017668378)

# %%
for column in df.columns:
    print(column, df[column].nunique())
# Out:
# User_ID 5891
# Product_ID 3623
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 17959

# %% [markdown]
# ## Analyzing Gender

# %%
df["Gender"].value_counts().plot(kind="pie", autopct="%.2f", title="Gender Ratio")
# Out:
# <Axes: title={'center': 'Gender Ratio'}, ylabel='count'>

# %%
df.groupby("Gender").size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df[df["Gender"] == "M"]
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 4                              4+               0                   8
# ...

# %%
df[df["Gender"] == "F"]["Purchase"].sum()
# Out:
# np.int64(1164624021)

# %%
df.groupby("Gender")["Purchase"].sum()
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.dtypes
# Out:
# User_ID                        int64
# Product_ID                    object
# Gender                        object
# Age                           object
# Occupation                     int64
# City_Category                 object
# Stay_In_Current_City_Years    object
# Marital_Status                 int64
# Product_Category_1             int64
# Purchase                       int64
# dtype: object

# %% [markdown]
# ## Analysing Age and Marital Status

# %%
df.groupby("Age").size().plot(kind="bar", figsize=(12,6), title="Age Distribution")
# Out:
# <Axes: title={'center': 'Age Distribution'}, xlabel='Age'>

# %% [markdown]
# ## Product bought by different age group

# %%
for i in df["Age"].unique():
    print(i, ":", len(df[df["Age"] == i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %% [markdown]
# ## Number of unique product bought by different age group

# %%
for i in df["Age"].unique():
    print(i, ":", df[df["Age"] == i]["Product_ID"].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
list1 = []
for i in df["Age"].unique():
    list1.append([i, df[df["Age"] == i]["Product_ID"].nunique()])

data = pd.DataFrame(list1, columns= ["Age group", " Unique Products"])
data
# Out:
#   Age group   Unique Products
# 0      0-17              2300
# 1       55+              2573
# 2     26-35              3419
# 3     46-50              3099
# 4     51-55              2877
# 5     36-45              3318
# 6     18-25              3213

# %%
data.plot.bar(x = "Age group")
# Out:
# <Axes: xlabel='Age group'>

# %% [markdown]
# ## Amount spent by Age

# %%
df.groupby("Age")["Purchase"].sum().plot(kind="bar", figsize=(12,6), title="Amount spent by age group")
# Out:
# <Axes: title={'center': 'Amount spent by age group'}, xlabel='Age'>

# %% [markdown]
# ## Average amount spent by age

# %%
df.groupby("Age")["Purchase"].mean()
# Out:
# Age
# 0-17     9020.126878
# 18-25    9235.197575
# 26-35    9314.588970
# 36-45    9401.478758
# 46-50    9284.872277
# 51-55    9620.616620
# 55+      9453.898579
# Name: Purchase, dtype: float64

# %%
df.groupby("Age")["Purchase"].mean().plot(kind="pie", autopct = "%.1f", figsize=(12,6), title="Amount spent by age group")
# Out:
# <Axes: title={'center': 'Amount spent by age group'}, ylabel='Purchase'>

# %%
df.groupby("Marital_Status").size().plot(kind="pie", autopct="%0.2f")
# Out:
# <Axes: >

# %%
df.groupby("Gender").size().plot(kind="pie", autopct="%0.2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Multi Column analysis

# %%
sns.set_theme(rc = {"figure.figsize" : (12,6)})
sns.countplot(x="Age", hue="Gender", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set_theme(rc = {"figure.figsize" : (12,6)})
sns.countplot(x="Gender", hue="Age", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set_theme(rc = {"figure.figsize" : (6,6)})
sns.countplot(x="Gender", hue="Marital_Status", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set_theme(rc = {"figure.figsize" : (6,6)})
sns.countplot(x="Marital_Status", hue="Gender", data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = df["City_Category"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x ="City_Category", hue="Age", data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x ="City_Category", hue="Gender", data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category")["Purchase"].sum()
# Out:
# City_Category
# A    1295668797
# B    2083431612
# C    1638567969
# Name: Purchase, dtype: int64

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("City_Category")["Purchase"].mean().plot(kind="pie", autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Occupation and Product Analysis

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x = df["Stay_In_Current_City_Years"], hue = "Gender", data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df["Stay_In_Current_City_Years"], hue = "Marital_Status", data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = df["Stay_In_Current_City_Years"], hue = "City_Category", data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years")["Purchase"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby("Stay_In_Current_City_Years")["Purchase"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x = df["Occupation"])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# ## Occupation buying most number of product

# %%
df.groupby("Occupation").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Purchase"].sum().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# ## occupation buying expensive products

# %%
df.groupby("Occupation")["Purchase"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x= "Occupation", hue="Gender", data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x= "Occupation", hue="Marital_Status", data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation")["Product_ID"].nunique().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# ## Which product has been bought most

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1")["Purchase"].sum().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1")["Purchase"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %% [markdown]
# ## Highest selling products

# %%
df.groupby("Product_ID")["Purchase"].sum().nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID")["Purchase"].size().nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
df.groupby("Product_ID")["Purchase"].mean().nlargest(10).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_ID'>

# %%
sns.countplot(x= "Product_Category_1", hue="Marital_Status", data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x= "Product_Category_1", hue="Gender", data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# ## Combining Marital Status and Gender

# %%
list2 = []
for i in range(len(df)):
    list2.append(df["Gender"][i] +"-"+ str(df["Marital_Status"][i]))

df["Marital_Gender"] = list2

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Marital_Gender
# 0            F-0
# 1            F-0
# 2            F-0
# 3            F-0
# 4            M-0

# %%
sns.countplot(x = df["Marital_Gender"])
# Out:
# <Axes: xlabel='Marital_Gender', ylabel='count'>

# %%
sns.countplot(x = "Age", hue="Marital_Gender", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = "Product_Category_1", hue="Marital_Gender", data=df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = "City_Category", hue="Marital_Gender", data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = "Age", hue="Marital_Gender", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ### Unmarried Men are buying more
